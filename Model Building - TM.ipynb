# %% [markdown]
# # AMC Theatre Analytics

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from patsy import dmatrices

#import decisiontreeclassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
#import logisticregression classifier
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
#import knn classifier
from sklearn.neighbors import KNeighborsClassifier

#for validating your classification model
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import cross_val_score
from sklearn import metrics
from sklearn.metrics import roc_curve, auc

# feature selection
from sklearn.feature_selection import RFE
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv("AMCSampleData_InsiderPremier.csv")
print df.head()
# Out:
#    ISPREMIER  AGE21PLUSINDICATOR  AGE18TO21INDICATOR  AGE13TO18INDICATOR  \
# 0          1                   1                   0                   0
# 1          1                   1                   0                   0
# 2          1                   1                   0                   0
# 3          0                   1                   0                   0
# 4          1                   1                   0                   0
#
#    GENDERCODE   BIRTHDATE  AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# 0           3   1/13/1976                                        0
# 1           1    7/6/1983                                        0
# 2           3  10/20/1970                                        0
# 3           0   7/10/1967                                        0
# 4           1    8/1/1994                                        1
#
#    AMCSTUBSREWARDSEMAILOPTININDICATOR  AMCSTUBSREWARDSMOBILEOPTININDICATOR  \
# 0                                   0                                    0
# 1                                   0                                    1
# 2                                   0                                    0
# 3                                   1                                    1
# 4                                   1                                    1
#
#    AMCSTUBSREWARDSSMSOPTININDICATOR        ...          \
# 0                                 0        ...
# 1                                 0        ...
# 2                                 0        ...
# 3                                 0        ...
# 4                                 0        ...
#
#    ONLINEFEESWAIVEDAMOUNT  ESTIMATEDINCOMERANGE  \
# 0                   61.25                     0
# 1                  123.00                     3
# 2                  182.50                     0
# 3                   47.75                     9
# 4                   45.00                     8
#
#    ESTIMATEDHOMEMARKETVALUERANGE  CHILDRENPRESENCE  \
# 0                              0                 3
# 1                             13                 0
# 2                              0                 3
# 3                             13                 1
# 4                              6                 3
#
#    HASFREQUENTVISITTHEATRENUMBER  TICKETQTYSUM  TICKETBALANCEDUESUM  \
# 0                              1            51               969.09
# 1                              0            40               842.00
# 2                              1            49               675.66
# 3                              1            38               616.61
# 4                              1            47               607.53
#
#    CONCQTYSUM  CONCLOYDISCOUNTAMTSUM  CONCBALANCEDUESUM
# 0           7                    0.0              41.71
# 1           1                   -1.0               7.49
# 2           4                    0.0              25.42
# 3          72                   -7.0             474.14
# 4          10                   -2.0              63.60
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47168 entries, 0 to 47167
# Data columns (total 24 columns):
# ISPREMIER                                   47168 non-null int64
# AGE21PLUSINDICATOR                          47168 non-null int64
# AGE18TO21INDICATOR                          47168 non-null int64
# AGE13TO18INDICATOR                          47168 non-null int64
# GENDERCODE                                  47168 non-null int64
# BIRTHDATE                                   47168 non-null object
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     47168 non-null int64
# AMCSTUBSREWARDSEMAILOPTININDICATOR          47168 non-null int64
# AMCSTUBSREWARDSMOBILEOPTININDICATOR         47168 non-null int64
# AMCSTUBSREWARDSSMSOPTININDICATOR            47168 non-null int64
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR    47168 non-null int64
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR       47168 non-null int64
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT          47168 non-null float64
# LIFETIMEAMCSTUBSSPENDAMOUNT                 47168 non-null float64
# ONLINEFEESWAIVEDAMOUNT                      47168 non-null float64
# ESTIMATEDINCOMERANGE                        47168 non-null int64
# ESTIMATEDHOMEMARKETVALUERANGE               47168 non-null int64
# CHILDRENPRESENCE                            47168 non-null int64
# HASFREQUENTVISITTHEATRENUMBER               47168 non-null int64
# TICKETQTYSUM                                47168 non-null int64
# TICKETBALANCEDUESUM                         47168 non-null float64
# CONCQTYSUM                                  47168 non-null int64
# CONCLOYDISCOUNTAMTSUM                       47168 non-null float64
# CONCBALANCEDUESUM                           47168 non-null float64
# dtypes: float64(6), int64(17), object(1)
# memory usage: 8.6+ MB

# %%
# drop unnecessary columns
df = df.drop(['BIRTHDATE'], axis = 1)

# %%
# correlation 
df.corr()
# Out:
#                                           ISPREMIER  AGE21PLUSINDICATOR  \
# ISPREMIER                                  1.000000            0.061112
# AGE21PLUSINDICATOR                         0.061112            1.000000
# AGE18TO21INDICATOR                        -0.055834           -0.752175
# AGE13TO18INDICATOR                        -0.055062           -0.575614
# GENDERCODE                                -0.259107           -0.045974
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR    0.017670           -0.021198
# AMCSTUBSREWARDSEMAILOPTININDICATOR         0.016929           -0.011316
# AMCSTUBSREWARDSMOBILEOPTININDICATOR        0.096219           -0.018910
# AMCSTUBSREWARDSSMSOPTININDICATOR          -0.002351           -0.008260
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR   0.101791           -0.018470
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR     -0.002351           -0.008260
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT         0.216813            0.039300
# LIFETIMEAMCSTUBSSPENDAMOUNT                0.220822            0.040100
# ONLINEFEESWAIVEDAMOUNT                     0.065082            0.014899
# ESTIMATEDINCOMERANGE                       0.131807            0.066996
# ESTIMATEDHOMEMARKETVALUERANGE              0.136758            0.053564
# CHILDRENPRESENCE                          -0.109527           -0.054983
# HASFREQUENTVISITTHEATRENUMBER             -0.095963            0.036750
# TICKETQTYSUM                               0.454074            0.070456
# TICKETBALANCEDUESUM                        0.448898            0.064970
# CONCQTYSUM                                 0.337030            0.048383
# CONCLOYDISCOUNTAMTSUM                     -0.336218           -0.030221
# CONCBALANCEDUESUM                          0.346307            0.050361
#
#                                           AGE18TO21INDICATOR  \
# ISPREMIER                                          -0.055834
# AGE21PLUSINDICATOR                                 -0.752175
# AGE18TO21INDICATOR                                  1.000000
# AGE13TO18INDICATOR                                 -0.050069
# GENDERCODE                                          0.031229
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR            -0.000344
# AMCSTUBSREWARDSEMAILOPTININDICATOR                 -0.003268
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                -0.006016
# AMCSTUBSREWARDSSMSOPTININDICATOR                   -0.001702
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR           -0.006367
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR              -0.001702
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                 -0.036603
# LIFETIMEAMCSTUBSSPENDAMOUNT                        -0.037039
# ONLINEFEESWAIVEDAMOUNT                             -0.014371
# ESTIMATEDINCOMERANGE                               -0.049905
# ESTIMATEDHOMEMARKETVALUERANGE                      -0.038279
# CHILDRENPRESENCE                                    0.043359
# HASFREQUENTVISITTHEATRENUMBER                      -0.012676
# TICKETQTYSUM                                       -0.052170
# TICKETBALANCEDUESUM                                -0.044477
# CONCQTYSUM                                         -0.044913
# CONCLOYDISCOUNTAMTSUM                               0.028610
# CONCBALANCEDUESUM                                  -0.045631
#
#                                           AGE13TO18INDICATOR  GENDERCODE  \
# ISPREMIER                                          -0.055062   -0.259107
# AGE21PLUSINDICATOR                                 -0.575614   -0.045974
# AGE18TO21INDICATOR                                 -0.050069    0.031229
# AGE13TO18INDICATOR                                  1.000000    0.038517
# GENDERCODE                                          0.038517    1.000000
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR             0.031067    0.049828
# AMCSTUBSREWARDSEMAILOPTININDICATOR                  0.021269    0.015141
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                 0.031597    0.288459
# AMCSTUBSREWARDSSMSOPTININDICATOR                   -0.001304    0.003246
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR            0.031809    0.275386
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR              -0.001304    0.003246
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                 -0.024832   -0.018750
# LIFETIMEAMCSTUBSSPENDAMOUNT                        -0.026132   -0.020644
# ONLINEFEESWAIVEDAMOUNT                             -0.013728   -0.033293
# ESTIMATEDINCOMERANGE                               -0.053198   -0.211743
# ESTIMATEDHOMEMARKETVALUERANGE                      -0.044290   -0.243629
# CHILDRENPRESENCE                                    0.044753    0.198341
# HASFREQUENTVISITTHEATRENUMBER                      -0.039047    0.042094
# TICKETQTYSUM                                       -0.066338   -0.161999
# TICKETBALANCEDUESUM                                -0.062233   -0.157961
# CONCQTYSUM                                         -0.039085   -0.030185
# CONCLOYDISCOUNTAMTSUM                               0.026098    0.097442
# CONCBALANCEDUESUM                                  -0.040643   -0.025590
#
#                                           AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# ISPREMIER                                                                0.017670
# AGE21PLUSINDICATOR                                                      -0.021198
# AGE18TO21INDICATOR                                                      -0.000344
# AGE13TO18INDICATOR                                                       0.031067
# GENDERCODE                                                               0.049828
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                                  1.000000
# AMCSTUBSREWARDSEMAILOPTININDICATOR                                       0.790356
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                                      0.417696
# AMCSTUBSREWARDSSMSOPTININDICATOR                                         0.003084
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                                 0.421257
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                                    0.003084
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                                      -0.004214
# LIFETIMEAMCSTUBSSPENDAMOUNT                                             -0.004993
# ONLINEFEESWAIVEDAMOUNT                                                  -0.031632
# ESTIMATEDINCOMERANGE                                                    -0.062426
# ESTIMATEDHOMEMARKETVALUERANGE                                           -0.085104
# CHILDRENPRESENCE                                                         0.049842
# HASFREQUENTVISITTHEATRENUMBER                                           -0.035628
# TICKETQTYSUM                                                            -0.055879
# TICKETBALANCEDUESUM                                                     -0.091406
# CONCQTYSUM                                                               0.123013
# CONCLOYDISCOUNTAMTSUM                                                   -0.038158
# CONCBALANCEDUESUM                                                        0.127483
#
#                                           AMCSTUBSREWARDSEMAILOPTININDICATOR  \
# ISPREMIER                                                           0.016929
# AGE21PLUSINDICATOR                                                 -0.011316
# AGE18TO21INDICATOR                                                 -0.003268
# AGE13TO18INDICATOR                                                  0.021269
# GENDERCODE                                                          0.015141
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                             0.790356
# AMCSTUBSREWARDSEMAILOPTININDICATOR                                  1.000000
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                                 0.346564
# AMCSTUBSREWARDSSMSOPTININDICATOR                                    0.002637
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                            0.350151
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                               0.002637
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                                 -0.016527
# LIFETIMEAMCSTUBSSPENDAMOUNT                                        -0.016877
# ONLINEFEESWAIVEDAMOUNT                                             -0.029093
# ESTIMATEDINCOMERANGE                                               -0.061998
# ESTIMATEDHOMEMARKETVALUERANGE                                      -0.078715
# CHILDRENPRESENCE                                                    0.050123
# HASFREQUENTVISITTHEATRENUMBER                                      -0.021071
# TICKETQTYSUM                                                       -0.050431
# TICKETBALANCEDUESUM                                                -0.077944
# CONCQTYSUM                                                          0.101356
# CONCLOYDISCOUNTAMTSUM                                              -0.029910
# CONCBALANCEDUESUM                                                   0.105160
#
#                                           AMCSTUBSREWARDSMOBILEOPTININDICATOR  \
# ISPREMIER                                                            0.096219
# AGE21PLUSINDICATOR                                                  -0.018910
# AGE18TO21INDICATOR                                                  -0.006016
# AGE13TO18INDICATOR                                                   0.031597
# GENDERCODE                                                           0.288459
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                              0.417696
# AMCSTUBSREWARDSEMAILOPTININDICATOR                                   0.346564
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                                  1.000000
# AMCSTUBSREWARDSSMSOPTININDICATOR                                    -0.000040
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                             0.981348
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                               -0.000040
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                                   0.008946
# LIFETIMEAMCSTUBSSPENDAMOUNT                                          0.009735
# ONLINEFEESWAIVEDAMOUNT                                              -0.033784
# ESTIMATEDINCOMERANGE                                                -0.201097
# ESTIMATEDHOMEMARKETVALUERANGE                                       -0.220956
# CHILDRENPRESENCE                                                     0.187706
# HASFREQUENTVISITTHEATRENUMBER                                        0.038848
# TICKETQTYSUM                                                        -0.003603
# TICKETBALANCEDUESUM                                                 -0.031016
# CONCQTYSUM                                                           0.216142
# CONCLOYDISCOUNTAMTSUM                                               -0.064730
# CONCBALANCEDUESUM                                                    0.224316
#
#                                           AMCSTUBSREWARDSSMSOPTININDICATOR  \
# ISPREMIER                                                        -0.002351
# AGE21PLUSINDICATOR                                               -0.008260
# AGE18TO21INDICATOR                                               -0.001702
# AGE13TO18INDICATOR                                               -0.001304
# GENDERCODE                                                        0.003246
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                           0.003084
# AMCSTUBSREWARDSEMAILOPTININDICATOR                                0.002637
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                              -0.000040
# AMCSTUBSREWARDSSMSOPTININDICATOR                                  1.000000
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                         -0.006617
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                             1.000000
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                                0.024336
# LIFETIMEAMCSTUBSSPENDAMOUNT                                       0.023447
# ONLINEFEESWAIVEDAMOUNT                                           -0.000020
# ESTIMATEDINCOMERANGE                                              0.015693
# ESTIMATEDHOMEMARKETVALUERANGE                                     0.017376
# CHILDRENPRESENCE                                                 -0.013487
# HASFREQUENTVISITTHEATRENUMBER                                     0.002147
# TICKETQTYSUM                                                     -0.002186
# TICKETBALANCEDUESUM                                              -0.002947
# CONCQTYSUM                                                       -0.003012
# CONCLOYDISCOUNTAMTSUM                                             0.001265
# CONCBALANCEDUESUM                                                -0.003093
#
#                                           AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR  \
# ISPREMIER                                                                 0.101791
# AGE21PLUSINDICATOR                                                       -0.018470
# AGE18TO21INDICATOR                                                       -0.006367
# AGE13TO18INDICATOR                                                        0.031809
# GENDERCODE                                                                0.275386
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                                   0.421257
# AMCSTUBSREWARDSEMAILOPTININDICATOR                                        0.350151
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                                       0.981348
# AMCSTUBSREWARDSSMSOPTININDICATOR                                         -0.006617
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                                  1.000000
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                                    -0.006617
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                                        0.006002
# LIFETIMEAMCSTUBSSPENDAMOUNT                                               0.006755
# ONLINEFEESWAIVEDAMOUNT                                                   -0.033195
# ESTIMATEDINCOMERANGE                                                     -0.196742
# ESTIMATEDHOMEMARKETVALUERANGE                                            -0.216951
# CHILDRENPRESENCE                                                          0.183563
# HASFREQUENTVISITTHEATRENUMBER                                             0.038253
# TICKETQTYSUM                                                             -0.000434
# TICKETBALANCEDUESUM                                                      -0.029483
# CONCQTYSUM                                                                0.217107
# CONCLOYDISCOUNTAMTSUM                                                    -0.067576
# CONCBALANCEDUESUM                                                         0.224778
#
#                                                 ...          \
# ISPREMIER                                       ...
# AGE21PLUSINDICATOR                              ...
# AGE18TO21INDICATOR                              ...
# AGE13TO18INDICATOR                              ...
# GENDERCODE                                      ...
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR         ...
# AMCSTUBSREWARDSEMAILOPTININDICATOR              ...
# AMCSTUBSREWARDSMOBILEOPTININDICATOR             ...
# AMCSTUBSREWARDSSMSOPTININDICATOR                ...
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR        ...
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR           ...
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT              ...
# LIFETIMEAMCSTUBSSPENDAMOUNT                     ...
# ONLINEFEESWAIVEDAMOUNT                          ...
# ESTIMATEDINCOMERANGE                            ...
# ESTIMATEDHOMEMARKETVALUERANGE                   ...
# CHILDRENPRESENCE                                ...
# HASFREQUENTVISITTHEATRENUMBER                   ...
# TICKETQTYSUM                                    ...
# TICKETBALANCEDUESUM                             ...
# CONCQTYSUM                                      ...
# CONCLOYDISCOUNTAMTSUM                           ...
# CONCBALANCEDUESUM                               ...
#
#                                           ONLINEFEESWAIVEDAMOUNT  \
# ISPREMIER                                               0.065082
# AGE21PLUSINDICATOR                                      0.014899
# AGE18TO21INDICATOR                                     -0.014371
# AGE13TO18INDICATOR                                     -0.013728
# GENDERCODE                                             -0.033293
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                -0.031632
# AMCSTUBSREWARDSEMAILOPTININDICATOR                     -0.029093
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                    -0.033784
# AMCSTUBSREWARDSSMSOPTININDICATOR                       -0.000020
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR               -0.033195
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                  -0.000020
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                      0.163019
# LIFETIMEAMCSTUBSSPENDAMOUNT                             0.168731
# ONLINEFEESWAIVEDAMOUNT                                  1.000000
# ESTIMATEDINCOMERANGE                                    0.069327
# ESTIMATEDHOMEMARKETVALUERANGE                           0.070886
# CHILDRENPRESENCE                                       -0.053465
# HASFREQUENTVISITTHEATRENUMBER                           0.017855
# TICKETQTYSUM                                            0.141154
# TICKETBALANCEDUESUM                                     0.156851
# CONCQTYSUM                                              0.073518
# CONCLOYDISCOUNTAMTSUM                                  -0.052441
# CONCBALANCEDUESUM                                       0.074391
#
#                                           ESTIMATEDINCOMERANGE  \
# ISPREMIER                                             0.131807
# AGE21PLUSINDICATOR                                    0.066996
# AGE18TO21INDICATOR                                   -0.049905
# AGE13TO18INDICATOR                                   -0.053198
# GENDERCODE                                           -0.211743
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR              -0.062426
# AMCSTUBSREWARDSEMAILOPTININDICATOR                   -0.061998
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                  -0.201097
# AMCSTUBSREWARDSSMSOPTININDICATOR                      0.015693
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR             -0.196742
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                 0.015693
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                    0.263728
# LIFETIMEAMCSTUBSSPENDAMOUNT                           0.265613
# ONLINEFEESWAIVEDAMOUNT                                0.069327
# ESTIMATEDINCOMERANGE                                  1.000000
# ESTIMATEDHOMEMARKETVALUERANGE                         0.738953
# CHILDRENPRESENCE                                     -0.825128
# HASFREQUENTVISITTHEATRENUMBER                        -0.107149
# TICKETQTYSUM                                          0.178424
# TICKETBALANCEDUESUM                                   0.162959
# CONCQTYSUM                                            0.116859
# CONCLOYDISCOUNTAMTSUM                                -0.098573
# CONCBALANCEDUESUM                                     0.118612
#
#                                           ESTIMATEDHOMEMARKETVALUERANGE  \
# ISPREMIER                                                      0.136758
# AGE21PLUSINDICATOR                                             0.053564
# AGE18TO21INDICATOR                                            -0.038279
# AGE13TO18INDICATOR                                            -0.044290
# GENDERCODE                                                    -0.243629
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                       -0.085104
# AMCSTUBSREWARDSEMAILOPTININDICATOR                            -0.078715
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                           -0.220956
# AMCSTUBSREWARDSSMSOPTININDICATOR                               0.017376
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                      -0.216951
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                          0.017376
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                             0.259035
# LIFETIMEAMCSTUBSSPENDAMOUNT                                    0.261709
# ONLINEFEESWAIVEDAMOUNT                                         0.070886
# ESTIMATEDINCOMERANGE                                           0.738953
# ESTIMATEDHOMEMARKETVALUERANGE                                  1.000000
# CHILDRENPRESENCE                                              -0.644154
# HASFREQUENTVISITTHEATRENUMBER                                 -0.118899
# TICKETQTYSUM                                                   0.189420
# TICKETBALANCEDUESUM                                            0.188621
# CONCQTYSUM                                                     0.104734
# CONCLOYDISCOUNTAMTSUM                                         -0.093199
# CONCBALANCEDUESUM                                              0.104829
#
#                                           CHILDRENPRESENCE  \
# ISPREMIER                                        -0.109527
# AGE21PLUSINDICATOR                               -0.054983
# AGE18TO21INDICATOR                                0.043359
# AGE13TO18INDICATOR                                0.044753
# GENDERCODE                                        0.198341
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR           0.049842
# AMCSTUBSREWARDSEMAILOPTININDICATOR                0.050123
# AMCSTUBSREWARDSMOBILEOPTININDICATOR               0.187706
# AMCSTUBSREWARDSSMSOPTININDICATOR                 -0.013487
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR          0.183563
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR            -0.013487
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT               -0.223837
# LIFETIMEAMCSTUBSSPENDAMOUNT                      -0.225148
# ONLINEFEESWAIVEDAMOUNT                           -0.053465
# ESTIMATEDINCOMERANGE                             -0.825128
# ESTIMATEDHOMEMARKETVALUERANGE                    -0.644154
# CHILDRENPRESENCE                                  1.000000
# HASFREQUENTVISITTHEATRENUMBER                     0.101970
# TICKETQTYSUM                                     -0.156023
# TICKETBALANCEDUESUM                              -0.134300
# CONCQTYSUM                                       -0.101341
# CONCLOYDISCOUNTAMTSUM                             0.082755
# CONCBALANCEDUESUM                                -0.101710
#
#                                           HASFREQUENTVISITTHEATRENUMBER  \
# ISPREMIER                                                     -0.095963
# AGE21PLUSINDICATOR                                             0.036750
# AGE18TO21INDICATOR                                            -0.012676
# AGE13TO18INDICATOR                                            -0.039047
# GENDERCODE                                                     0.042094
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR                       -0.035628
# AMCSTUBSREWARDSEMAILOPTININDICATOR                            -0.021071
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                            0.038848
# AMCSTUBSREWARDSSMSOPTININDICATOR                               0.002147
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR                       0.038253
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR                          0.002147
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                            -0.009548
# LIFETIMEAMCSTUBSSPENDAMOUNT                                   -0.000393
# ONLINEFEESWAIVEDAMOUNT                                         0.017855
# ESTIMATEDINCOMERANGE                                          -0.107149
# ESTIMATEDHOMEMARKETVALUERANGE                                 -0.118899
# CHILDRENPRESENCE                                               0.101970
# HASFREQUENTVISITTHEATRENUMBER                                  1.000000
# TICKETQTYSUM                                                   0.347209
# TICKETBALANCEDUESUM                                            0.327321
# CONCQTYSUM                                                     0.042238
# CONCLOYDISCOUNTAMTSUM                                         -0.032915
# CONCBALANCEDUESUM                                              0.044441
#
#                                           TICKETQTYSUM  TICKETBALANCEDUESUM  \
# ISPREMIER                                     0.454074             0.448898
# AGE21PLUSINDICATOR                            0.070456             0.064970
# AGE18TO21INDICATOR                           -0.052170            -0.044477
# AGE13TO18INDICATOR                           -0.066338            -0.062233
# GENDERCODE                                   -0.161999            -0.157961
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR      -0.055879            -0.091406
# AMCSTUBSREWARDSEMAILOPTININDICATOR           -0.050431            -0.077944
# AMCSTUBSREWARDSMOBILEOPTININDICATOR          -0.003603            -0.031016
# AMCSTUBSREWARDSSMSOPTININDICATOR             -0.002186            -0.002947
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR     -0.000434            -0.029483
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR        -0.002186            -0.002947
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT            0.311926             0.327504
# LIFETIMEAMCSTUBSSPENDAMOUNT                   0.329116             0.344369
# ONLINEFEESWAIVEDAMOUNT                        0.141154             0.156851
# ESTIMATEDINCOMERANGE                          0.178424             0.162959
# ESTIMATEDHOMEMARKETVALUERANGE                 0.189420             0.188621
# CHILDRENPRESENCE                             -0.156023            -0.134300
# HASFREQUENTVISITTHEATRENUMBER                 0.347209             0.327321
# TICKETQTYSUM                                  1.000000             0.931924
# TICKETBALANCEDUESUM                           0.931924             1.000000
# CONCQTYSUM                                    0.447647             0.399806
# CONCLOYDISCOUNTAMTSUM                        -0.298130            -0.268951
# CONCBALANCEDUESUM                             0.453148             0.411823
#
#                                           CONCQTYSUM  CONCLOYDISCOUNTAMTSUM  \
# ISPREMIER                                   0.337030              -0.336218
# AGE21PLUSINDICATOR                          0.048383              -0.030221
# AGE18TO21INDICATOR                         -0.044913               0.028610
# AGE13TO18INDICATOR                         -0.039085               0.026098
# GENDERCODE                                 -0.030185               0.097442
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     0.123013              -0.038158
# AMCSTUBSREWARDSEMAILOPTININDICATOR          0.101356              -0.029910
# AMCSTUBSREWARDSMOBILEOPTININDICATOR         0.216142              -0.064730
# AMCSTUBSREWARDSSMSOPTININDICATOR           -0.003012               0.001265
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR    0.217107              -0.067576
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR      -0.003012               0.001265
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT          0.308422              -0.193170
# LIFETIMEAMCSTUBSSPENDAMOUNT                 0.318169              -0.196434
# ONLINEFEESWAIVEDAMOUNT                      0.073518              -0.052441
# ESTIMATEDINCOMERANGE                        0.116859              -0.098573
# ESTIMATEDHOMEMARKETVALUERANGE               0.104734              -0.093199
# CHILDRENPRESENCE                           -0.101341               0.082755
# HASFREQUENTVISITTHEATRENUMBER               0.042238              -0.032915
# TICKETQTYSUM                                0.447647              -0.298130
# TICKETBALANCEDUESUM                         0.399806              -0.268951
# CONCQTYSUM                                  1.000000              -0.381125
# CONCLOYDISCOUNTAMTSUM                      -0.381125               1.000000
# CONCBALANCEDUESUM                           0.964272              -0.378498
#
#                                           CONCBALANCEDUESUM
# ISPREMIER                                          0.346307
# AGE21PLUSINDICATOR                                 0.050361
# AGE18TO21INDICATOR                                -0.045631
# AGE13TO18INDICATOR                                -0.040643
# GENDERCODE                                        -0.025590
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR            0.127483
# AMCSTUBSREWARDSEMAILOPTININDICATOR                 0.105160
# AMCSTUBSREWARDSMOBILEOPTININDICATOR                0.224316
# AMCSTUBSREWARDSSMSOPTININDICATOR                  -0.003093
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR           0.224778
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR             -0.003093
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT                 0.322353
# LIFETIMEAMCSTUBSSPENDAMOUNT                        0.332444
# ONLINEFEESWAIVEDAMOUNT                             0.074391
# ESTIMATEDINCOMERANGE                               0.118612
# ESTIMATEDHOMEMARKETVALUERANGE                      0.104829
# CHILDRENPRESENCE                                  -0.101710
# HASFREQUENTVISITTHEATRENUMBER                      0.044441
# TICKETQTYSUM                                       0.453148
# TICKETBALANCEDUESUM                                0.411823
# CONCQTYSUM                                         0.964272
# CONCLOYDISCOUNTAMTSUM                             -0.378498
# CONCBALANCEDUESUM                                  1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# # Model Building

# %%
# declare X variables and Y variables
y = df['ISPREMIER']
X = df.drop(['ISPREMIER'], axis=1)

# %% [markdown]
# # Recursive Feature Selection (RFE)

# %%
model = LogisticRegression()
rfe = RFE(model, 10)  #asking 10 best attributes
rfe = rfe.fit(X, y)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True  True  True  True  True False  True False  True False False False
#  False False False False  True  True False False  True False]
# [ 1  1  1  1  1  2  1 11  1 12  9 10 13  5  6  3  1  1  7  4  1  8]

# %%
# features sorted by their rank
pd.DataFrame({'feature':X.columns, 'importance':rfe.ranking_})
# Out:
#                                      feature  importance
# 0                         AGE21PLUSINDICATOR           1
# 1                         AGE18TO21INDICATOR           1
# 2                         AGE13TO18INDICATOR           1
# 3                                 GENDERCODE           1
# 4    AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR           1
# 5         AMCSTUBSREWARDSEMAILOPTININDICATOR           2
# 6        AMCSTUBSREWARDSMOBILEOPTININDICATOR           1
# 7           AMCSTUBSREWARDSSMSOPTININDICATOR          11
# 8   AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR           1
# 9      AMCSTUBSTHEATRESMSOFFEROPTININDICATOR          12
# 10        LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT           9
# 11               LIFETIMEAMCSTUBSSPENDAMOUNT          10
# 12                    ONLINEFEESWAIVEDAMOUNT          13
# 13                      ESTIMATEDINCOMERANGE           5
# 14             ESTIMATEDHOMEMARKETVALUERANGE           6
# 15                          CHILDRENPRESENCE           3
# 16             HASFREQUENTVISITTHEATRENUMBER           1
# 17                              TICKETQTYSUM           1
# 18                       TICKETBALANCEDUESUM           7
# 19                                CONCQTYSUM           4
# 20                     CONCLOYDISCOUNTAMTSUM           1
# 21                         CONCBALANCEDUESUM           8

# %%
# select 7 most significant features only - not selecting age variables
X_logistic = df[['GENDERCODE', 'AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR', 'AMCSTUBSREWARDSMOBILEOPTININDICATOR','AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR','HASFREQUENTVISITTHEATRENUMBER','TICKETQTYSUM','CONCLOYDISCOUNTAMTSUM']]
print X_logistic.head()
# Out:
#    GENDERCODE  AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# 0           3                                        0
# 1           1                                        0
# 2           3                                        0
# 3           0                                        0
# 4           1                                        1
#
#    AMCSTUBSREWARDSMOBILEOPTININDICATOR  \
# 0                                    0
# 1                                    1
# 2                                    0
# 3                                    1
# 4                                    1
#
#    AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR  HASFREQUENTVISITTHEATRENUMBER  \
# 0                                         0                              1
# 1                                         1                              0
# 2                                         0                              1
# 3                                         0                              1
# 4                                         1                              1
#
#    TICKETQTYSUM  CONCLOYDISCOUNTAMTSUM
# 0            51                    0.0
# 1            40                   -1.0
# 2            49                    0.0
# 3            38                   -7.0
# 4            47                   -2.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X_logistic, y, test_size=0.3, random_state=0)
lr = LogisticRegression()
lr.fit(X_train, y_train)

#Model evaluation
print metrics.accuracy_score(y_test, lr.predict(X_test))
print metrics.confusion_matrix(y_test, lr.predict(X_test))
print metrics.classification_report(y_test, lr.predict(X_test))
print metrics.roc_auc_score(y_test, lr.predict(X_test))
# Out:
# 0.923892304431
# [[12287   241]
#  [  836   787]]
#              precision    recall  f1-score   support
#
#           0       0.94      0.98      0.96     12528
#           1       0.77      0.48      0.59      1623
#
# avg / total       0.92      0.92      0.92     14151
#
# 0.73283379426

# %% [markdown]
# > **92.39% model accuracy**
# - **0.733 AUC score; AUC = Areaa Under Curve**
#     - TPR = (true positives/total positives) = 0.94
#     - FPR = (false positives/total negatives) = 0.77

# %% [markdown]
# # Logistic Regression

# %%
# evaluate the model by splitting into train and test sets (split validation)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
#You just did split valiation. 
#Report the following model evaluation metrics: overall model accuracy, confusion matrix, AUC score, classification report
print metrics.accuracy_score(y_test, lr.predict(X_test))
print metrics.confusion_matrix(y_test, lr.predict(X_test))
print metrics.classification_report(y_test, lr.predict(X_test))
print metrics.roc_auc_score(y_test, lr.predict(X_test))
# Out:
# 0.927920288319
# [[12296   232]
#  [  788   835]]
#              precision    recall  f1-score   support
#
#           0       0.94      0.98      0.96     12528
#           1       0.78      0.51      0.62      1623
#
# avg / total       0.92      0.93      0.92     14151
#
# 0.747980420346

# %% [markdown]
# > **92.8% model accuracy**
# - **0.748 AUC score; AUC = Area Under Curve**
#     - TPR = (true positives/total positives) = 0.94
#     - FPR = (false positives/total negatives) = 0.78

# %% [markdown]
# ## Logit Model

# %%
# instantiate a logit model, and fit with X_lr and y_lr
# this is like a statistical model, rather than a data mining model ...
logit = sm.Logit(y, X) 
model_logit = logit.fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.198089
#          Iterations: 35
# /Users/Trevor/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
print model_logit.predict()
# Out:
# [ 1.          1.          0.99999993 ...,  0.07482706  0.01434115
#   0.08737244]

# %%
# logit summary
print model_logit.summary()
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              ISPREMIER   No. Observations:                47168
# Model:                          Logit   Df Residuals:                    47147
# Method:                           MLE   Df Model:                           20
# Date:                Fri, 07 Jul 2017   Pseudo R-squ.:                  0.4460
# Time:                        19:07:12   Log-Likelihood:                -9343.5
# converged:                      False   LL-Null:                       -16866.
#                                         LLR p-value:                     0.000
# ============================================================================================================
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# AGE21PLUSINDICATOR                          -2.0198        nan        nan        nan         nan         nan
# AGE18TO21INDICATOR                          -2.6780      0.035    -76.446      0.000      -2.747      -2.609
# AGE13TO18INDICATOR                          -3.2284      0.060    -53.857      0.000      -3.346      -3.111
# GENDERCODE                                  -0.7337      0.018    -40.811      0.000      -0.769      -0.698
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     -0.2488      0.082     -3.028      0.002      -0.410      -0.088
# AMCSTUBSREWARDSEMAILOPTININDICATOR           0.1149      0.092      1.249      0.211      -0.065       0.295
# AMCSTUBSREWARDSMOBILEOPTININDICATOR          0.6485      0.148      4.379      0.000       0.358       0.939
# AMCSTUBSREWARDSSMSOPTININDICATOR            -9.0457   6.58e+19  -1.37e-19      1.000   -1.29e+20    1.29e+20
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR     0.8891      0.148      6.015      0.000       0.599       1.179
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR       -9.0457   6.58e+19  -1.37e-19      1.000   -1.29e+20    1.29e+20
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT           0.0915      0.008     11.163      0.000       0.075       0.108
# LIFETIMEAMCSTUBSSPENDAMOUNT                 -0.0094      0.001    -10.909      0.000      -0.011      -0.008
# ONLINEFEESWAIVEDAMOUNT                      -0.0021      0.001     -2.925      0.003      -0.003      -0.001
# ESTIMATEDINCOMERANGE                         0.0078      0.009      0.865      0.387      -0.010       0.026
# ESTIMATEDHOMEMARKETVALUERANGE               -0.0333      0.006     -5.731      0.000      -0.045      -0.022
# CHILDRENPRESENCE                             0.0415        nan        nan        nan         nan         nan
# HASFREQUENTVISITTHEATRENUMBER               -2.7830      0.064    -43.701      0.000      -2.908      -2.658
# TICKETQTYSUM                                 0.1479      0.013     11.413      0.000       0.123       0.173
# TICKETBALANCEDUESUM                          0.0252      0.001     19.030      0.000       0.023       0.028
# CONCQTYSUM                                  -0.0482      0.014     -3.386      0.001      -0.076      -0.020
# CONCLOYDISCOUNTAMTSUM                       -0.3928      0.015    -26.832      0.000      -0.421      -0.364
# CONCBALANCEDUESUM                            0.0195      0.003      7.260      0.000       0.014       0.025
# ============================================================================================================
# /Users/Trevor/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:1029: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# /Users/Trevor/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/Trevor/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/Trevor/anaconda/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
# logit pred_table()
model_logit.pred_table()
# Out:
# array([[ 40943.,    784.],
#        [  2639.,   2802.]])

# %%
# look at the confidence interval of each coeffecient
print model_logit.conf_int()
# Out:
#                                                      0             1
# AGE21PLUSINDICATOR                                 NaN           NaN
# AGE18TO21INDICATOR                       -2.746688e+00 -2.609367e+00
# AGE13TO18INDICATOR                       -3.345860e+00 -3.110885e+00
# GENDERCODE                               -7.689131e-01 -6.984431e-01
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  -4.098909e-01 -8.777185e-02
# AMCSTUBSREWARDSEMAILOPTININDICATOR       -6.534532e-02  2.951747e-01
# AMCSTUBSREWARDSMOBILEOPTININDICATOR       3.582846e-01  9.388133e-01
# AMCSTUBSREWARDSSMSOPTININDICATOR         -1.290225e+20  1.290225e+20
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR  5.993992e-01  1.178814e+00
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR    -1.290225e+20  1.290225e+20
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT        7.543243e-02  1.075617e-01
# LIFETIMEAMCSTUBSSPENDAMOUNT              -1.109674e-02 -7.716727e-03
# ONLINEFEESWAIVEDAMOUNT                   -3.430720e-03 -6.780029e-04
# ESTIMATEDINCOMERANGE                     -9.901777e-03  2.555205e-02
# ESTIMATEDHOMEMARKETVALUERANGE            -4.470724e-02 -2.192078e-02
# CHILDRENPRESENCE                                   NaN           NaN
# HASFREQUENTVISITTHEATRENUMBER            -2.907777e+00 -2.658151e+00
# TICKETQTYSUM                              1.225097e-01  1.733105e-01
# TICKETBALANCEDUESUM                       2.262744e-02  2.782353e-02
# CONCQTYSUM                               -7.617573e-02 -2.031497e-02
# CONCLOYDISCOUNTAMTSUM                    -4.214843e-01 -3.640999e-01
# CONCBALANCEDUESUM                         1.423596e-02  2.476588e-02

# %%
# odds ratios only
print np.exp(model_logit.params)
# Out:
# AGE21PLUSINDICATOR                          0.132682
# AGE18TO21INDICATOR                          0.068699
# AGE13TO18INDICATOR                          0.039622
# GENDERCODE                                  0.480140
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     0.779711
# AMCSTUBSREWARDSEMAILOPTININDICATOR          1.121778
# AMCSTUBSREWARDSMOBILEOPTININDICATOR         1.912763
# AMCSTUBSREWARDSSMSOPTININDICATOR            0.000118
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR    2.432955
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR       0.000118
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT          1.095814
# LIFETIMEAMCSTUBSSPENDAMOUNT                 0.990637
# ONLINEFEESWAIVEDAMOUNT                      0.997948
# ESTIMATEDINCOMERANGE                        1.007856
# ESTIMATEDHOMEMARKETVALUERANGE               0.967235
# CHILDRENPRESENCE                            1.042399
# HASFREQUENTVISITTHEATRENUMBER               0.061855
# TICKETQTYSUM                                1.159409
# TICKETBALANCEDUESUM                         1.025546
# CONCQTYSUM                                  0.952900
# CONCLOYDISCOUNTAMTSUM                       0.675169
# CONCBALANCEDUESUM                           1.019692
# dtype: float64

# %% [markdown]
# ## Build Stats Model

# %%
#import packages 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#regression packages
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
import statsmodels.formula.api as sm

#lasso regression
from sklearn import linear_model

#f_regression (feature selection)
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

# recursive feature selection (feature selection)
from sklearn.feature_selection import RFE

# %%
#build model with 7 significant variables identified in feature selection
reg_model = sm.ols("ISPREMIER~GENDERCODE+AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR+AMCSTUBSREWARDSMOBILEOPTININDICATOR+AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR+HASFREQUENTVISITTHEATRENUMBER+TICKETQTYSUM+CONCLOYDISCOUNTAMTSUM", df)
runs_model = reg_model.fit()
print runs_model.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              ISPREMIER   R-squared:                       0.361
# Model:                            OLS   Adj. R-squared:                  0.361
# Method:                 Least Squares   F-statistic:                     3812.
# Date:                Fri, 07 Jul 2017   Prob (F-statistic):               0.00
# Time:                        19:24:57   Log-Likelihood:                -2526.2
# No. Observations:               47168   AIC:                             5068.
# Df Residuals:                   47160   BIC:                             5139.
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    0.1928      0.004     47.642      0.000       0.185       0.201
# GENDERCODE                                  -0.0600      0.001    -51.506      0.000      -0.062      -0.058
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     -0.0288      0.003     -8.530      0.000      -0.035      -0.022
# AMCSTUBSREWARDSMOBILEOPTININDICATOR          0.0389      0.012      3.161      0.002       0.015       0.063
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR     0.0708      0.012      5.769      0.000       0.047       0.095
# HASFREQUENTVISITTHEATRENUMBER               -0.1746      0.003    -65.557      0.000      -0.180      -0.169
# TICKETQTYSUM                                 0.0381      0.000    108.925      0.000       0.037       0.039
# CONCLOYDISCOUNTAMTSUM                       -0.0563      0.001    -45.999      0.000      -0.059      -0.054
# ==============================================================================
# Omnibus:                    14194.584   Durbin-Watson:                   1.820
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            57717.266
# Skew:                           1.447   Prob(JB):                         0.00
# Kurtosis:                       7.582   Cond. No.                         70.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
