# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
amc = pd.read_csv("AMCSampleData_InsiderPremier.csv")
amc.head()
# Out:
#    ISPREMIER  AGE21PLUSINDICATOR  AGE18TO21INDICATOR  AGE13TO18INDICATOR  \
# 0          1                   1                   0                   0
# 1          1                   1                   0                   0
# 2          1                   1                   0                   0
# 3          0                   1                   0                   0
# 4          1                   1                   0                   0
#
#    GENDERCODE   BIRTHDATE  AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# 0           3   1/13/1976                                        0
# 1           1    7/6/1983                                        0
# 2           3  10/20/1970                                        0
# 3           0   7/10/1967                                        0
# 4           1    8/1/1994                                        1
#
#    AMCSTUBSREWARDSEMAILOPTININDICATOR  AMCSTUBSREWARDSMOBILEOPTININDICATOR  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
amc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47168 entries, 0 to 47167
# Data columns (total 24 columns):
# ISPREMIER                                   47168 non-null int64
# AGE21PLUSINDICATOR                          47168 non-null int64
# AGE18TO21INDICATOR                          47168 non-null int64
# AGE13TO18INDICATOR                          47168 non-null int64
# GENDERCODE                                  47168 non-null int64
# BIRTHDATE                                   47168 non-null object
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR     47168 non-null int64
# AMCSTUBSREWARDSEMAILOPTININDICATOR          47168 non-null int64
# AMCSTUBSREWARDSMOBILEOPTININDICATOR         47168 non-null int64
# AMCSTUBSREWARDSSMSOPTININDICATOR            47168 non-null int64
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR    47168 non-null int64
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR       47168 non-null int64
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT          47168 non-null float64
# ...

# %%
amc.describe()
# Out:
#           ISPREMIER  AGE21PLUSINDICATOR  AGE18TO21INDICATOR  \
# count  47168.000000        47168.000000        47168.000000
# mean       0.115354            0.892660            0.063920
# std        0.319452            0.309548            0.244614
# min        0.000000            0.000000            0.000000
# 25%        0.000000            1.000000            0.000000
# 50%        0.000000            1.000000            0.000000
# 75%        0.000000            1.000000            0.000000
# max        1.000000            1.000000            1.000000
#
#        AGE13TO18INDICATOR    GENDERCODE  \
# count        47168.000000  47168.000000
# mean             0.038543      2.460778
# std              0.192505      1.081705
# min              0.000000      0.000000
# 25%              0.000000      3.000000
# 50%              0.000000      3.000000
# 75%              0.000000      3.000000
# max              1.000000      3.000000
#
#        AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# ...

# %%
amc.corr()
# Out:
#                                           ISPREMIER  AGE21PLUSINDICATOR  \
# ISPREMIER                                  1.000000            0.061112
# AGE21PLUSINDICATOR                         0.061112            1.000000
# AGE18TO21INDICATOR                        -0.055834           -0.752175
# AGE13TO18INDICATOR                        -0.055062           -0.575614
# GENDERCODE                                -0.259107           -0.045974
# AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR    0.017670           -0.021198
# AMCSTUBSREWARDSEMAILOPTININDICATOR         0.016929           -0.011316
# AMCSTUBSREWARDSMOBILEOPTININDICATOR        0.096219           -0.018910
# AMCSTUBSREWARDSSMSOPTININDICATOR          -0.002351           -0.008260
# AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR   0.101791           -0.018470
# AMCSTUBSTHEATRESMSOFFEROPTININDICATOR     -0.002351           -0.008260
# LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT         0.216813            0.039300
# ...

# %% [markdown]
# From looking at the correlation analysis, there is a high positive correlation between those that are premier members and AGE21PLUSINDICATOR, AMCSTUBSREWARDSMOBILEOPTININDICATOR, AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR, LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT, LIFETIMEAMCSTUBSSPENDAMOUNT, ONLINEFEESWAIVEDAMOUNT, ESTIMATEDINCOMERANGE, ESTIMATEDHOMEMARKETVALUERANGE, TICKETQTYSUM, TICKETBALANCEDUESUM, CONCQTYSUM and CONCBALANCEDUESUM

# %%
amc.hist(figsize = (27,27))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000002C48E5F8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002B1A31D0>]], dtype=object)

# %%
plt.figure(figsize=(16,16))
sns.heatmap(amc.corr(), annot=True)

# %%
#regression packages
import sklearn.linear_model as lm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
import statsmodels.formula.api as sm

#lasso regression
from sklearn import linear_model

#f_regression (feature selection)
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest

# recursive feature selection (feature selection)
from sklearn.feature_selection import RFE

# %%
amc = amc.drop(['BIRTHDATE'], axis=1)
amc.head()
# Out:
#    ISPREMIER  AGE21PLUSINDICATOR  AGE18TO21INDICATOR  AGE13TO18INDICATOR  \
# 0          1                   1                   0                   0
# 1          1                   1                   0                   0
# 2          1                   1                   0                   0
# 3          0                   1                   0                   0
# 4          1                   1                   0                   0
#
#    GENDERCODE  AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR  \
# 0           3                                        0
# 1           1                                        0
# 2           3                                        0
# 3           0                                        0
# 4           1                                        1
#
#    AMCSTUBSREWARDSEMAILOPTININDICATOR  AMCSTUBSREWARDSMOBILEOPTININDICATOR  \
# 0                                   0                                    0
# ...

# %%
#assigning columns to X and Y variables
y = data['ISPREMIER'] 
X = data.drop(['ISPREMIER'], axis =1)

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: ISPREMIER, dtype: int64

# %% [markdown]
# ### Build Linear Regression model

# %%
#Build a linear regression model
model1 = lm.LinearRegression()
model1.fit(X, y)   
model1_y = model1.predict(X)

# %%
#Predicted y values
model1_y
# Out:
# array([ 2.56641623,  2.56463607,  1.9551649 , ...,  0.10498762,
#        -0.01020896,  0.11803383])

# %%
print 'Coefficients: ', model1.coef_
print "y-intercept ", model1.intercept_
# Out:
# Coefficients:  [ -1.58537368e-01  -1.88935244e-01  -2.03078164e-01  -6.09963589e-02
#   -2.44840163e-02  -1.00774400e-03   2.51809051e-02  -2.25561359e-02
#    7.60864108e-02  -2.25561359e-02   6.82924144e-03  -6.98213669e-04
#   -1.64395467e-04   2.35408549e-03  -1.65526137e-03   7.81323363e-03
#   -1.70247685e-01   1.81096443e-02   1.91027293e-03  -4.03659831e-03
#   -5.10607804e-02   1.55405596e-03]
# y-intercept  0.333369547308

# %%
# The coefficients
print 'Coefficients: ', model1.coef_
# y-intercept
print "y-intercept ", model1.intercept_
# Out:
# Coefficients:  [ -1.58537368e-01  -1.88935244e-01  -2.03078164e-01  -6.09963589e-02
#   -2.44840163e-02  -1.00774400e-03   2.51809051e-02  -2.25561359e-02
#    7.60864108e-02  -2.25561359e-02   6.82924144e-03  -6.98213669e-04
#   -1.64395467e-04   2.35408549e-03  -1.65526137e-03   7.81323363e-03
#   -1.70247685e-01   1.81096443e-02   1.91027293e-03  -4.03659831e-03
#   -5.10607804e-02   1.55405596e-03]
# y-intercept  0.333369547308

# %%
pd.DataFrame(zip(X.columns, np.transpose(model1.coef_)))
# Out:
#                                            0         1
# 0                         AGE21PLUSINDICATOR -0.158537
# 1                         AGE18TO21INDICATOR -0.188935
# 2                         AGE13TO18INDICATOR -0.203078
# 3                                 GENDERCODE -0.060996
# 4    AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR -0.024484
# 5         AMCSTUBSREWARDSEMAILOPTININDICATOR -0.001008
# 6        AMCSTUBSREWARDSMOBILEOPTININDICATOR  0.025181
# 7           AMCSTUBSREWARDSSMSOPTININDICATOR -0.022556
# 8   AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR  0.076086
# 9      AMCSTUBSTHEATRESMSOFFEROPTININDICATOR -0.022556
# 10        LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT  0.006829
# 11               LIFETIMEAMCSTUBSSPENDAMOUNT -0.000698
# 12                    ONLINEFEESWAIVEDAMOUNT -0.000164
# 13                      ESTIMATEDINCOMERANGE  0.002354
# 14             ESTIMATEDHOMEMARKETVALUERANGE -0.001655
# 15                          CHILDRENPRESENCE  0.007813
# ...

# %%
print "mean square error: ", mean_squared_error(y, model1_y)
print "variance or r-squared: ", explained_variance_score(y, model1_y)
# Out:
# mean square error:  0.0635769061531
# variance or r-squared:  0.376985110649

# %%
lr = lm.LinearRegression()
rfe = RFE(lr, n_features_to_select = 2)
rfe_y = rfe.fit(X,y)

# print the results
print "Features sorted by their rank:"
print sorted(zip(map(lambda x: x, rfe.ranking_), X.columns))
# Out:
# Features sorted by their rank:
# [(1, 'AGE13TO18INDICATOR'), (1, 'AGE18TO21INDICATOR'), (2, 'AGE21PLUSINDICATOR'), (3, 'CONCLOYDISCOUNTAMTSUM'), (4, 'AMCSTUBSTHEATREMOBILEOFFEROPTININDICATOR'), (5, 'GENDERCODE'), (6, 'HASFREQUENTVISITTHEATRENUMBER'), (7, 'TICKETQTYSUM'), (8, 'AMCSTUBSREWARDSMOBILEOPTININDICATOR'), (9, 'AMCSTUBSLOYALTYEMAILOFFEROPTININDICATOR'), (10, 'CHILDRENPRESENCE'), (11, 'CONCQTYSUM'), (12, 'TICKETBALANCEDUESUM'), (13, 'ESTIMATEDINCOMERANGE'), (14, 'ESTIMATEDHOMEMARKETVALUERANGE'), (15, 'AMCSTUBSREWARDSEMAILOPTININDICATOR'), (16, 'CONCBALANCEDUESUM'), (17, 'AMCSTUBSTHEATRESMSOFFEROPTININDICATOR'), (18, 'AMCSTUBSREWARDSSMSOPTININDICATOR'), (19, 'LIFETIMEAMCSTUBSAWARDSEARNEDAMOUNT'), (20, 'LIFETIMEAMCSTUBSSPENDAMOUNT'), (21, 'ONLINEFEESWAIVEDAMOUNT')]

# %% [markdown]
# ### Build Logistic Regression model

# %%
logRegModel = LogisticRegression()
rfe = RFE(logRegModel, 3)
rfe = rfe.fit(X, y)
